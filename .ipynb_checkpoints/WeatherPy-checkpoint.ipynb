# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from scipy.stats import linregress

# Import API key
from hw6_api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
new_cities = []
lat = []
lng = []
date = []
temp = []
humidity = []
clouds = []
wind = []
country = []
record = 1

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        date.append(response['dt'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        print(f"Processing Record {record} | {city}")
        record += 1
        new_cities.append(city)
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 | fortuna
# Processing Record 2 | longyearbyen
# Processing Record 3 | turmalina
# Processing Record 4 | barrow
# City not found. Skipping...
# Processing Record 5 | mataura
# Processing Record 6 | oranjemund
# Processing Record 7 | suba
# Processing Record 8 | flin flon
# Processing Record 9 | linxia
# Processing Record 10 | masallatah
# Processing Record 11 | maroua
# Processing Record 12 | ushuaia
# Processing Record 13 | jamestown
# Processing Record 14 | andros town
# Processing Record 15 | dikson
# Processing Record 16 | kivsharivka
# Processing Record 17 | rikitea
# Processing Record 18 | port alfred
# Processing Record 19 | marsh harbour
# Processing Record 20 | upernavik
# Processing Record 21 | hermanus
# Processing Record 22 | ossora
# Processing Record 23 | hithadhoo
# Processing Record 24 | uzyn
# Processing Record 25 | kapaa
# Processing Record 26 | carinhanha
# Processing Record 27 | sitka
# Processing Record 28 | inta
# Processing Record 29 | busselton
# Processing Record 30 | aksarka
# Processing Record 31 | norman wells
# Processing Record 32 | johi
# Processing Record 33 | puerto ayora
# Processing Record 34 | hobart
# Processing Record 35 | sao filipe
# Processing Record 36 | lebu
# Processing Record 37 | chiang khong
# Processing Record 38 | carnarvon
# Processing Record 39 | pangai
# Processing Record 40 | kulhudhuffushi
# Processing Record 41 | nikolskoye
# Processing Record 42 | butaritari
# Processing Record 43 | husavik
# Processing Record 44 | gravdal
# Processing Record 45 | cape town
# Processing Record 46 | saint-philippe
# Processing Record 47 | codrington
# Processing Record 48 | iqaluit
# Processing Record 49 | coihaique
# Processing Record 50 | bela
# Processing Record 51 | punta arenas
# Processing Record 52 | sokoni
# Processing Record 53 | sergeyevka
# Processing Record 54 | kodiak
# Processing Record 55 | pevek
# Processing Record 56 | bima
# Processing Record 57 | deputatskiy
# Processing Record 58 | lavrentiya
# Processing Record 59 | mocuba
# Processing Record 60 | hilo
# Processing Record 61 | mar del plata
# Processing Record 62 | poum
# Processing Record 63 | guerrero negro
# Processing Record 64 | qaanaaq
# Processing Record 65 | provideniya
# Processing Record 66 | oxford
# Processing Record 67 | eureka
# Processing Record 68 | albany
# Processing Record 69 | east london
# City not found. Skipping...
# Processing Record 70 | hirado
# Processing Record 71 | new norfolk
# Processing Record 72 | rawson
# Processing Record 73 | bredasdorp
# Processing Record 74 | thompson
# Processing Record 75 | souillac
# Processing Record 76 | morgan city
# Processing Record 77 | romitan
# Processing Record 78 | saskylakh
# Processing Record 79 | wattegama
# Processing Record 80 | esperance
# Processing Record 81 | port elizabeth
# Processing Record 82 | castro
# Processing Record 83 | ribeira grande
# Processing Record 84 | general cepeda
# Processing Record 85 | port-gentil
# Processing Record 86 | metro
# Processing Record 87 | mahebourg
# Processing Record 88 | castleblayney
# Processing Record 89 | skjervoy
# Processing Record 90 | avarua
# Processing Record 91 | bethel
# Processing Record 92 | victoria
# Processing Record 93 | hasaki
# Processing Record 94 | richards bay
# Processing Record 95 | khatanga
# Processing Record 96 | zabid
# Processing Record 97 | geraldton
# Processing Record 98 | cobh
# Processing Record 99 | turbat
# Processing Record 100 | bluff
# Processing Record 101 | yamada
# Processing Record 102 | faanui
# Processing Record 103 | vaini
# Processing Record 104 | mujiayingzi
# Processing Record 105 | yellowknife
# Processing Record 106 | jardim
# Processing Record 107 | zhuhai
# Processing Record 108 | ancud
# Processing Record 109 | bambous virieux
# Processing Record 110 | meulaboh
# Processing Record 111 | saint anthony
# Processing Record 112 | isangel
# Processing Record 113 | ajdabiya
# Processing Record 114 | santiago del estero
# Processing Record 115 | ponta do sol
# City not found. Skipping...
# Processing Record 116 | jaltenango
# Processing Record 117 | setermoen
# Processing Record 118 | matagami
# Processing Record 119 | grootfontein
# Processing Record 120 | leningradskiy
# Processing Record 121 | bilma
# Processing Record 122 | gwadar
# Processing Record 123 | tasiilaq
# Processing Record 124 | la ronge
# Processing Record 125 | lagoa
# Processing Record 126 | emet
# Processing Record 127 | vaitape
# Processing Record 128 | gullhaug
# Processing Record 129 | ilulissat
# Processing Record 130 | owando
# Processing Record 131 | cockburn town
# Processing Record 132 | lasa
# Processing Record 133 | hays
# Processing Record 134 | faya
# Processing Record 135 | kawalu
# Processing Record 136 | nemuro
# Processing Record 137 | auch
# Processing Record 138 | ninghai
# Processing Record 139 | san quintin
# Processing Record 140 | clyde river
# Processing Record 141 | manhuacu
# Processing Record 142 | doha
# Processing Record 143 | galesong
# Processing Record 144 | moreira sales
# Processing Record 145 | severo-kurilsk
# Processing Record 146 | aykhal
# Processing Record 147 | kuminskiy
# Processing Record 148 | saint george
# Processing Record 149 | vanimo
# Processing Record 150 | buala
# Processing Record 151 | salalah
# Processing Record 152 | steti
# Processing Record 153 | lima
# Processing Record 154 | aksu
# Processing Record 155 | olafsvik
# Processing Record 156 | rosarito
# Processing Record 157 | spirit river
# Processing Record 158 | berlevag
# Processing Record 159 | atuona
# Processing Record 160 | tocopilla
# Processing Record 161 | kazanskoye
# Processing Record 162 | pastos bons
# Processing Record 163 | porciuncula
# Processing Record 164 | labuhan
# Processing Record 165 | kilindoni
# Processing Record 166 | cherskiy
# Processing Record 167 | cidreira
# Processing Record 168 | henderson
# Processing Record 169 | awjilah
# Processing Record 170 | namatanai
# Processing Record 171 | bandarbeyla
# Processing Record 172 | kirkwood
# Processing Record 173 | cabo san lucas
# Processing Record 174 | joensuu
# Processing Record 175 | ivanovka
# Processing Record 176 | sangar
# Processing Record 177 | siddipet
# Processing Record 178 | riberalta
# Processing Record 179 | dingle
# Processing Record 180 | san felipe
# Processing Record 181 | mitu
# Processing Record 182 | luderitz
# Processing Record 183 | chuy
# Processing Record 184 | kenai
# Processing Record 185 | makamba
# Processing Record 186 | tazovskiy
# Processing Record 187 | asyut
# Processing Record 188 | kloulklubed
# Processing Record 189 | chifeng
# Processing Record 190 | unai
# Processing Record 191 | igarka
# Processing Record 192 | anadyr
# Processing Record 193 | honiara
# Processing Record 194 | payo
# Processing Record 195 | sirawai
# Processing Record 196 | grand forks
# Processing Record 197 | avigliano
# Processing Record 198 | mwinilunga
# Processing Record 199 | arlit
# Processing Record 200 | krasnoselkup
# Processing Record 201 | shima
# Processing Record 202 | heinola
# Processing Record 203 | grand gaube
# Processing Record 204 | xining
# Processing Record 205 | cayenne
# Processing Record 206 | chumikan
# Processing Record 207 | macia
# Processing Record 208 | diffa
# Processing Record 209 | rio grande
# Processing Record 210 | san antonio
# Processing Record 211 | arman
# Processing Record 212 | kasongo-lunda
# Processing Record 213 | murgab
# Processing Record 214 | sackville
# Processing Record 215 | tateyama
# Processing Record 216 | tezu
# Processing Record 217 | arraial do cabo
# Processing Record 218 | tangping
# Processing Record 219 | unity
# Processing Record 220 | tuatapere
# Processing Record 221 | ambilobe
# Processing Record 222 | jiazi
# Processing Record 223 | dalbandin
# Processing Record 224 | portland
# Processing Record 225 | bilopillya
# Processing Record 226 | utrecht
# Processing Record 227 | bridgetown
# Processing Record 228 | beloha
# Processing Record 229 | ponta delgada
# Processing Record 230 | kavieng
# Processing Record 231 | ambulu
# Processing Record 232 | te anau
# Processing Record 233 | yumen
# Processing Record 234 | torbay
# Processing Record 235 | atar
# Processing Record 236 | camacha
# Processing Record 237 | ayagoz
# Processing Record 238 | mindelo
# Processing Record 239 | laredo
# Processing Record 240 | santa cruz
# Processing Record 241 | ciudad bolivar
# Processing Record 242 | hobyo
# Processing Record 243 | poplar bluff
# Processing Record 244 | dunedin
# Processing Record 245 | gamba
# Processing Record 246 | leshukonskoye
# Processing Record 247 | nanortalik
# Processing Record 248 | porto-vecchio
# Processing Record 249 | mitsamiouli
# Processing Record 250 | san policarpo
# Processing Record 251 | porterville
# Processing Record 252 | rio gallegos
# Processing Record 253 | smidovich
# Processing Record 254 | mattru
# Processing Record 255 | langevag
# Processing Record 256 | alofi
# Processing Record 257 | west plains
# Processing Record 258 | masindi
# Processing Record 259 | mabaruma
# Processing Record 260 | inhambane
# Processing Record 261 | port said
# Processing Record 262 | yerbogachen
# Processing Record 263 | ojinaga
# Processing Record 264 | shenjiamen
# Processing Record 265 | saldanha
# Processing Record 266 | sola
# Processing Record 267 | port moresby
# Processing Record 268 | yeppoon
# Processing Record 269 | polis
# Processing Record 270 | kuching
# Processing Record 271 | ocean city
# Processing Record 272 | north battleford
# Processing Record 273 | nigde
# Processing Record 274 | knysna
# Processing Record 275 | klaksvik
# Processing Record 276 | tuktoyaktuk
# Processing Record 277 | kaitangata
# Processing Record 278 | ostrovnoy
# Processing Record 279 | ixtapa
# Processing Record 280 | lompoc
# Processing Record 281 | georgetown
# Processing Record 282 | auki
# Processing Record 283 | coahuayana
# Processing Record 284 | umm kaddadah
# Processing Record 285 | okhotsk
# Processing Record 286 | vestmanna
# Processing Record 287 | portobelo
# Processing Record 288 | port blair
# Processing Record 289 | yatou
# Processing Record 290 | la sarre
# Processing Record 291 | daru
# Processing Record 292 | sidi ali
# Processing Record 293 | ofunato
# Processing Record 294 | dalvik
# Processing Record 295 | omsukchan
# Processing Record 296 | sal rei
# Processing Record 297 | hami
# Processing Record 298 | portel
# Processing Record 299 | san angelo
# Processing Record 300 | milkovo
# Processing Record 301 | seminole
# Processing Record 302 | pran buri
# Processing Record 303 | shenzhen
# Processing Record 304 | manica
# Processing Record 305 | novokizhinginsk
# Processing Record 306 | yabelo
# Processing Record 307 | sayyan
# Processing Record 308 | dickinson
# Processing Record 309 | nagato
# Processing Record 310 | vardo
# Processing Record 311 | khao yoi
# Processing Record 312 | aranos
# Processing Record 313 | moranbah
# Processing Record 314 | kafr sawm
# Processing Record 315 | sasaram
# City not found. Skipping...
# Processing Record 316 | calabozo
# Processing Record 317 | samarai
# Processing Record 318 | raga
# Processing Record 319 | ballina
# Processing Record 320 | capinopolis
# Processing Record 321 | tautira
# Processing Record 322 | ola
# Processing Record 323 | calatagan
# Processing Record 324 | kirkuk
# Processing Record 325 | beringovskiy
# Processing Record 326 | scarborough
# Processing Record 327 | nawa
# Processing Record 328 | semnan
# Processing Record 329 | kyaikkami
# Processing Record 330 | constitucion
# Processing Record 331 | eregli
# Processing Record 332 | igaci
# Processing Record 333 | srednekolymsk
# Processing Record 334 | airai
# Processing Record 335 | rognan
# Processing Record 336 | la asuncion
# Processing Record 337 | ukholovo
# Processing Record 338 | hamilton
# Processing Record 339 | presidencia roque saenz pena
# Processing Record 340 | menzelinsk
# Processing Record 341 | hokitika
# Processing Record 342 | hervey bay
# Processing Record 343 | necochea
# Processing Record 344 | klisura
# Processing Record 345 | tiksi
# Processing Record 346 | miracema do tocantins
# Processing Record 347 | acarau
# Processing Record 348 | paamiut
# Processing Record 349 | narsaq
# Processing Record 350 | grand-santi
# Processing Record 351 | mosquera
# Processing Record 352 | coquimbo
# Processing Record 353 | hofn
# Processing Record 354 | luga
# Processing Record 355 | kavaratti
# Processing Record 356 | ulaanbaatar
# Processing Record 357 | porto novo
# Processing Record 358 | lata
# Processing Record 359 | simao
# Processing Record 360 | adrar
# Processing Record 361 | naze
# Processing Record 362 | margate
# Processing Record 363 | oistins
# Processing Record 364 | harper
# Processing Record 365 | cozumel
# Processing Record 366 | montepuez
# Processing Record 367 | mecca
# Processing Record 368 | linjiang
# Processing Record 369 | iisalmi
# Processing Record 370 | merauke
# Processing Record 371 | port lincoln
# Processing Record 372 | vila velha
# Processing Record 373 | cabadiangan
# Processing Record 374 | chokurdakh
# Processing Record 375 | vallenar
# Processing Record 376 | mayo
# Processing Record 377 | touros
# Processing Record 378 | vendychany
# Processing Record 379 | kayseri
# Processing Record 380 | leskolovo
# Processing Record 381 | ushtobe
# Processing Record 382 | asau
# Processing Record 383 | baykit
# Processing Record 384 | cuamba
# Processing Record 385 | benito juarez
# Processing Record 386 | leh
# Processing Record 387 | balkhash
# Processing Record 388 | westport
# Processing Record 389 | gharghoda
# Processing Record 390 | bengkulu
# Processing Record 391 | kalamata
# Processing Record 392 | altayskoye
# Processing Record 393 | pisco
# Processing Record 394 | ucluelet
# Processing Record 395 | norwood
# Processing Record 396 | meinedo
# Processing Record 397 | mount isa
# Processing Record 398 | san cristobal
# Processing Record 399 | ahuimanu
# Processing Record 400 | tessaoua
# Processing Record 401 | vestmannaeyjar
# Processing Record 402 | kindu
# Processing Record 403 | tall kayf
# Processing Record 404 | yarmouth
# Processing Record 405 | novoagansk
# Processing Record 406 | pipar
# Processing Record 407 | melilla
# Processing Record 408 | benicarlo
# Processing Record 409 | bud
# Processing Record 410 | baiyin
# Processing Record 411 | telimele
# Processing Record 412 | san patricio
# Processing Record 413 | kidal
# Processing Record 414 | dicabisagan
# Processing Record 415 | nome
# Processing Record 416 | birao
# Processing Record 417 | port hedland
# Processing Record 418 | zavolzhsk
# Processing Record 419 | saint-paul
# Processing Record 420 | soe
# Processing Record 421 | muros
# Processing Record 422 | ghanzi
# Processing Record 423 | kalavai
# Processing Record 424 | kahului
# Processing Record 425 | san rafael del sur
# Processing Record 426 | hualmay
# Processing Record 427 | noboribetsu
# Processing Record 428 | shelburne
# Processing Record 429 | fairbanks
# Processing Record 430 | chapais
# Processing Record 431 | palana
# Processing Record 432 | acari
# Processing Record 433 | paracuru
# Processing Record 434 | dareda
# Processing Record 435 | sydney
# Processing Record 436 | waingapu
# Processing Record 437 | kungurtug
# Processing Record 438 | okha
# Processing Record 439 | yulara
# Processing Record 440 | prudnik
# Processing Record 441 | panzhihua
# Processing Record 442 | dwarka
# Processing Record 443 | bata
# Processing Record 444 | codajas
# Processing Record 445 | cabinda
# Processing Record 446 | tomatlan
# Processing Record 447 | hermiston
# Processing Record 448 | weligama
# Processing Record 449 | bodaybo
# Processing Record 450 | tulagi
# Processing Record 451 | beitbridge
# Processing Record 452 | the pas
# Processing Record 453 | tura
# Processing Record 454 | omboue
# Processing Record 455 | kununurra
# Processing Record 456 | tambura
# Processing Record 457 | sioux lookout
# Processing Record 458 | shakawe
# Processing Record 459 | akdepe
# Processing Record 460 | bathsheba
# Processing Record 461 | nantong
# Processing Record 462 | kruisfontein
# Processing Record 463 | haines junction
# Processing Record 464 | kotido
# Processing Record 465 | tiznit
# Processing Record 466 | flinders
# Processing Record 467 | sao francisco
# Processing Record 468 | manggar
# Processing Record 469 | walvis bay
# Processing Record 470 | nokaneng
# Processing Record 471 | imbituba
# Processing Record 472 | san juan
# Processing Record 473 | beyla
# Processing Record 474 | tilichiki
# Processing Record 475 | nouadhibou
# Processing Record 476 | mount gambier
# Processing Record 477 | xam nua
# Processing Record 478 | yar-sale
# Processing Record 479 | brigantine
# Processing Record 480 | katsuura
# Processing Record 481 | dudinka
# Processing Record 482 | teya
# Processing Record 483 | kem
# Processing Record 484 | tarauaca
# Processing Record 485 | el reno
# Processing Record 486 | vao
# Processing Record 487 | alekseyevsk
# Processing Record 488 | peniche
# Processing Record 489 | filingue
# Processing Record 490 | korla
# Processing Record 491 | kardla
# Processing Record 492 | pacasmayo
# Processing Record 493 | ibra
# Processing Record 494 | east lansing
# Processing Record 495 | prince rupert
# Processing Record 496 | tabas
# Processing Record 497 | lucapa
# Processing Record 498 | berdigestyakh
# Processing Record 499 | sao caetano de odivelas
# Processing Record 500 | tete
# Processing Record 501 | barcelos
# Processing Record 502 | pangkalanbuun
# Processing Record 503 | vranov
# Processing Record 504 | ayorou
# Processing Record 505 | nantucket
# Processing Record 506 | kichera
# Processing Record 507 | killybegs
# Processing Record 508 | araouane
# Processing Record 509 | asfi
# Processing Record 510 | harrisonburg
# Processing Record 511 | owatonna
# Processing Record 512 | kaeo
# Processing Record 513 | laguna
# Processing Record 514 | turayf
# Processing Record 515 | erdenet
# Processing Record 516 | digri
# Processing Record 517 | anacortes
# Processing Record 518 | paraiso
# Processing Record 519 | pemangkat
# Processing Record 520 | nizhnyaya tavda
# Processing Record 521 | sur
# Processing Record 522 | sibolga
# Processing Record 523 | roebourne
# Processing Record 524 | lebork
# Processing Record 525 | vostok
# Processing Record 526 | sungaipenuh
# Processing Record 527 | chkalovsk
# Processing Record 528 | komsomolskiy
# Processing Record 529 | havoysund
# Processing Record 530 | namibe
# Processing Record 531 | yining
# Processing Record 532 | seydi
# Processing Record 533 | quatre cocos
# Processing Record 534 | kalaleh
# Processing Record 535 | goderich
# Processing Record 536 | andenes
# Processing Record 537 | diamantino
# Processing Record 538 | jalu
# Processing Record 539 | belmonte
# Processing Record 540 | matipo
# Processing Record 541 | sassandra
# Processing Record 542 | kieta
# Processing Record 543 | manado
# Processing Record 544 | puerto del rosario
# Processing Record 545 | karratha
# Processing Record 546 | zhigansk
# Processing Record 547 | parakou
# Processing Record 548 | vagur
# Processing Record 549 | nayoro
# Processing Record 550 | dire
# Processing Record 551 | najran
# Processing Record 552 | alexandria
# Processing Record 553 | lekoni
# Processing Record 554 | kasongo
# Processing Record 555 | karibib
# Processing Record 556 | caravelas
# Processing Record 557 | chimore
# Processing Record 558 | mayumba
# Processing Record 559 | witu
# Processing Record 560 | raudeberg
# Processing Record 561 | waipawa
# Processing Record 562 | okato
# Processing Record 563 | grand falls
# Processing Record 564 | aklavik
# Processing Record 565 | sumbe
# Processing Record 566 | chicama
# Processing Record 567 | lucea

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": new_cities,
    "Cloudiness": clouds,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": temp,
    "Wind Speed": wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %%
weather_data['Date'] = pd.to_datetime(weather_data['Date'], unit='s')
weather_data.head()
# Out:
#            City  Cloudiness Country                Date  Humidity    Lat  \
# 0       fortuna           1      US 2020-03-21 15:17:31        93  40.60
# 1  longyearbyen         100      SJ 2020-03-21 15:17:31        96  78.22
# 2     turmalina          84      BR 2020-03-21 15:14:23        71 -17.29
# 3        barrow          90      US 2020-03-21 15:17:31        78  71.29
# 4       mataura         100      NZ 2020-03-21 15:17:31        94 -46.19
#
#       Lng  Max Temp  Wind Speed
# 0 -124.16     39.20       11.41
# 1   15.64     12.49        5.10
# 2  -42.73     78.73        8.37
# 3 -156.79      8.60        5.82
# 4  168.86     53.01        1.01

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_values = weather_data['Lat']
y_values = weather_data['Max Temp']
plt.scatter(x_values,y_values,linewidths='1',edgecolors='b')
plt.title('City Latitude vs Max Temperature (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_values = weather_data['Lat']
y_values = weather_data['Humidity']
plt.scatter(x_values,y_values,linewidths='1',edgecolors='r')
plt.title('City Latitude vs Humidity (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_values = weather_data['Lat']
y_values = weather_data['Cloudiness']
plt.scatter(x_values,y_values, c='g', linewidths='1')
plt.title('City Latitude vs Cloudiness (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_values = weather_data['Lat']
y_values = weather_data['Wind Speed']
plt.scatter(x_values,y_values, c='k', linewidths='1')
plt.title('City Latitude vs Wind Speed (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north_cond = (weather_data['Lat'] >= 0)
south_cond = (weather_data['Lat'] < 0)

north_data = weather_data[north_cond]
south_data = weather_data[south_cond]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_data['Lat']
y_values = north_data['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values,linewidths='1',edgecolors='b')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40, 100),fontsize=15,color="red")
plt.title('City Latitude vs Max Temperature (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_data['Lat']
y_values = south_data['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values,linewidths='1',edgecolors='b')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30, 50),fontsize=15,color="red")
plt.title('City Latitude vs Max Temperature (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_data['Lat']
y_values = north_data['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values,linewidths='1',edgecolors='r')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 10),fontsize=15,color="red")
plt.title('City Latitude vs Humidity (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_data['Lat']
y_values = south_data['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values,linewidths='1',edgecolors='r')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 20),fontsize=15,color="red")
plt.title('City Latitude vs Humidity (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_data['Lat']
y_values = north_data['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values, c='g')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 41),fontsize=15,color="red")
plt.title('City Latitude vs Cloudiness (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_data['Lat']
y_values = south_data['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values, c='g')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 40),fontsize=15,color="red")
plt.title('City Latitude vs Cloudiness (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_data['Lat']
y_values = north_data['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values, c='k')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0, 30),fontsize=15,color="red")
plt.title('City Latitude vs Wind Speed (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.show()
#print(f"{line_eq}")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_data['Lat']
y_values = south_data['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values,y_values, c='k')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.title('City Latitude vs Wind Speed (03/21/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.show()
#print(f"{line_eq}")
